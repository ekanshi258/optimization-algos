# %% [markdown]
# <a href="https://colab.research.google.com/github/ekanshi258/optimization-algos/blob/master/benchmark_pso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Single Objective
#
# Trying out different benchmark problems to observe the behaviour of PSO on different contours.
#
# ### **Initial Population: Randomised**

# %%
pip install pymoo

# %% [markdown]
# Imports:

# %%
from pymoo.algorithms.so_pso import PSO, PSOAnimation
from pymoo.factory import Ackley
from pymoo.optimize import minimize

# %% [markdown]
# _____
# ### Ackley

# %%
import numpy as np
from pymoo.factory import get_problem, get_visualization

problem = get_problem("ackley", n_var=2, a=20, b=1/5, c=2 * np.pi)
get_visualization("fitness-landscape", problem, angle=(45, 45), _type="surface").show()

# %%
problem = Ackley()

algorithm = PSO(max_velocity_rate=0.025)

res = minimize(problem,
               algorithm,
               seed=1,
               save_history=True,
               verbose=False)

# %%
print("X: ", res.X)
print("Obj: ", res.F)
print("Constraints: ", res.G)
print("Execution time: ", res.exec_time)
# Out:
# X:  [-7.94956179e-09  1.07254590e-07]
# Obj:  [3.04194228e-07]
# Constraints:  None
# Execution time:  0.8864355087280273

# %% [markdown]
# Convergence:

# %%
import matplotlib.pyplot as plt
import numpy as np

n_evals = np.array([e.evaluator.n_eval for e in res.history])
opt = np.array([e.opt[0].F for e in res.history])
plt.figure(figsize=(12,6))
plt.title("Ackley - PSO")
plt.plot(n_evals, opt, "-")
plt.yscale("log")
plt.show()

# %% [markdown]
# _____
# ### Rastrigin

# %%
problem = get_problem("rastrigin", n_var=2)
get_visualization("fitness-landscape", problem, angle=(45, 45), _type="surface").show()

# %%
from pymoo.factory import Rastrigin
problem = Rastrigin()

algorithm = PSO()

res = minimize(problem,
               algorithm,
               seed=1,
               save_history=True,
               verbose=False)

# %%
print("X: ", res.X)
print("Obj: ", res.F)
print("Constraints: ", res.G)
print("Execution time: ", res.exec_time)
# Out:
# X:  [-2.17873238e-07 -2.73407327e-08]
# Obj:  [9.56390522e-12]
# Constraints:  None
# Execution time:  0.7213883399963379

# %% [markdown]
# Convergence:

# %%
n_evals = np.array([e.evaluator.n_eval for e in res.history])
opt = np.array([e.opt[0].F for e in res.history])
plt.figure(figsize=(12,6))
plt.title("Rastrigin - PSO")
plt.plot(n_evals, opt, "-")
plt.yscale("log")
plt.show()

# %% [markdown]
# _____
# ### Rosenbrock

# %%
problem = get_problem("rosenbrock", n_var=2)
get_visualization("fitness-landscape", problem, angle=(45, 45), _type="surface").show()

# %%
from pymoo.factory import Rosenbrock
problem = Rosenbrock()

algorithm = PSO()

res = minimize(problem,
               algorithm,
               seed=1,
               save_history=True,
               verbose=False)

# %%
print("X: ", res.X)
print("Obj: ", res.F)
print("Constraints: ", res.G)
print("Execution time: ", res.exec_time)
# Out:
# X:  [1.00003783 1.00006474]
# Obj:  [1.33300858e-08]
# Constraints:  None
# Execution time:  1.617300271987915

# %% [markdown]
# Convergence:

# %%
n_evals = np.array([e.evaluator.n_eval for e in res.history])
opt = np.array([e.opt[0].F for e in res.history])
plt.figure(figsize=(12,6))
plt.title("Rosenbrock - PSO")
plt.plot(n_evals, opt, "-")
plt.yscale("log")
plt.show()

# %% [markdown]
# ____
# ### Griewank

# %%
problem = get_problem("griewank", n_var=1)
plot = get_visualization("fitness-landscape", problem, _type="surface", n_samples=1000)
plot.show()

# %%
from pymoo.factory import Griewank
problem = Griewank()

algorithm = PSO()

res = minimize(problem,
               algorithm,
               seed=1,
               save_history=True,
               verbose=False)

# %%
print("X: ", res.X)
print("Obj: ", res.F)
print("Constraints: ", res.G)
print("Execution time: ", res.exec_time)
# Out:
# X:  [-3.13959993 -4.43844865]
# Obj:  [0.00739613]
# Constraints:  None
# Execution time:  2.3548054695129395

# %%
n_evals = np.array([e.evaluator.n_eval for e in res.history])
opt = np.array([e.opt[0].F for e in res.history])
plt.figure(figsize=(12,6))
plt.title("Griewank - PSO")
plt.plot(n_evals, opt, "-")
plt.yscale("log")
plt.show()

# %% [markdown]
# ______
# ### Zakharov

# %%
problem = get_problem("zakharov", n_var=2)
get_visualization("fitness-landscape", problem, angle=(45, 45), _type="surface").show()

# %%
from pymoo.factory import Zakharov
problem = Zakharov()

algorithm = PSO()

res = minimize(problem,
               algorithm,
               seed=1,
               save_history=True,
               verbose=False)

# %%
print("X: ", res.X)
print("Obj: ", res.F)
print("Constraints: ", res.G)
print("Execution time: ", res.exec_time)
# Out:
# X:  [ 8.77136942e-06 -3.68662235e-06]
# Obj:  [9.10167941e-11]
# Constraints:  None
# Execution time:  0.6657636165618896

# %% [markdown]
# Convergence:

# %%
n_evals = np.array([e.evaluator.n_eval for e in res.history])
opt = np.array([e.opt[0].F for e in res.history])
plt.figure(figsize=(12,6))
plt.title("Zakharov - PSO")
plt.plot(n_evals, opt, "-")
plt.yscale("log")
plt.show()
